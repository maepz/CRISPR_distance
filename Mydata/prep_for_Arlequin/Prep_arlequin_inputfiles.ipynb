# %% [markdown]
# # Generate arlequin input file

# %% [markdown]
# Input files are structured into two main sections with additional subsections that must
# appear in the following order:
#
# 1) Profile section (mandatory)
#
# 2) Data section (mandatory)
#
#     2a) Haplotype list (optional)
#
#     2b) Distance matrices (optional)
#
#     2c) Samples (mandatory)
#
#     2d) Genetic structure (optional)
#
#     2e) Mantel tests (optional)

# %%
entry=''

# %% [markdown]
# ## Profile section

# %%
header="[Profile]\n"
title=''
nsamples=41
GenotypicData=0
LocusSeparator='WHITESPACE'
DataType='FREQUENCY'

################################
lines=[header,'\t\t'+'Title="'+title+'"','\t\tNbSamples='+str(nsamples),'\t\tGenotypicData='+str(GenotypicData),'\t\tLocusSeparator='+str(LocusSeparator),'\t\tDataType='+DataType]


profile_section='\n'.join(lines)
entry+=profile_section+'\n'
print(profile_section)
# Out:
# [Profile]
#
# 		Title=""
# 		NbSamples=41
# 		GenotypicData=0
# 		LocusSeparator=WHITESPACE
# 		DataType=FREQUENCY

# %% [markdown]
# ## Data section

# %%
header_dat='[Data]\n'
entry+=header_dat+'\n'

# %% [markdown]
# ### Distance matrix

# %%
import pandas as pd
import numpy as np

file='/Users/maeperez/Desktop/CRISPR_R/arrays_in_whole_dataset_v6_pairwiseDist'
dist=pd.read_csv(file+'.csv',header=0,index_col=0,sep='\t')
   
header_dist='\t[[DistanceMatrix]]\n'
MatrixName="A given distance matrix"
MatrixSize= len(dist)
LabelPosition='LINE'
MatrixDatafile=file+'.dis'

### write triangular distance matrix
dist = dist.where(np.tril(np.ones(dist.shape)).astype(np.bool))
dist_str = ['\t'.join(map(str,list(filter(lambda x: np.isfinite(x), np_array))+[0])) for np_array in dist.values]
dist_str=['\t'.join(map(str,dist.columns))]+dist_str
dist_str
with open(MatrixDatafile, 'w') as the_file:
    the_file.write('\n'.join(dist_str))

# %%
#########################

lines=[header_dist,'\t\tMatrixName="'+MatrixName+'"','\t\tMatrixSize='+str(MatrixSize),'\t\tLabelPosition='+LabelPosition,'\t\tMatrixData=EXTERN "'+MatrixDatafile+'"']

dist_section='\n'.join(lines)
print(dist_section)
entry+=dist_section+'\n'
# Out:
# 	[[DistanceMatrix]]
#
# 		MatrixName="A given distance matrix"
# 		MatrixSize=123
# 		LabelPosition=LINE
# 		MatrixData=EXTERN "/Users/maeperez/Desktop/CRISPR_R/arrays_in_whole_dataset_v6_pairwiseDist.dis"

# %% [markdown]
# ### Samples

# %%
file='/Users/maeperez/Desktop/CRISPR_R/ALLCRISPRs_haplo_matches_at_5_dist_V6_sorted.txt'
pop=pd.read_csv(file,header=0,sep=',',index_col=0)

header_dist='\t[[Samples]]\n'

sample_section=header_dist+'\n'
pop.shape
pop=pop.drop(10)
pop.shape
pop=pop.reset_index()
pop=pop.iloc[:,2:]
# pop[:10]

#########
# pop=pop[:10]
file='/Users/maeperez/Desktop/CRISPR_R/ALLCRISPRs_haplo_matches_at_5_dist_V6_sorted.txt'
pop
# Out:
#      R09L-3-T  R16L-4-T  R08H-1-T  R07B-2-Tc  R07B-1-Ta  R02H-8-T  R15H-3-T  \
# 0         NaN       NaN       NaN        NaN        NaN       NaN       1.0
# 1         NaN       NaN       NaN        NaN        NaN       NaN       NaN
# 2       169.0       2.0     198.0        8.0      106.0      83.0       1.0
# 3         NaN       NaN       NaN        NaN        NaN       NaN       NaN
# 4         NaN       NaN       1.0        NaN        NaN       NaN       NaN
# ..        ...       ...       ...        ...        ...       ...       ...
# 118       NaN       NaN       NaN        NaN        NaN       NaN       NaN
# 119       NaN       NaN       NaN        NaN        NaN       NaN       NaN
# 120       NaN       NaN       NaN        NaN        NaN       NaN       NaN
# 121       NaN       NaN       NaN        NaN        NaN       NaN       NaN
# 122       NaN       NaN       NaN        NaN        NaN       NaN       NaN
#
#      R15H-7-T  R16L-3-T  R07B-3-T  ...  R15H-2-T_bis  R08H-2-Ta  R02H-9-T  \
# 0         NaN       NaN       NaN  ...           NaN        NaN       NaN
# 1         NaN       NaN       NaN  ...           NaN        NaN       NaN
# 2         3.0       3.0      97.0  ...           5.0      219.0      51.0
# 3         NaN       NaN       NaN  ...           NaN        NaN       NaN
# 4         NaN       NaN       2.0  ...           NaN        NaN       1.0
# ..        ...       ...       ...  ...           ...        ...       ...
# 118       NaN       NaN       NaN  ...           NaN        NaN       NaN
# 119       NaN       NaN       NaN  ...           NaN        NaN       NaN
# 120       NaN       NaN       NaN  ...           NaN        NaN       NaN
# 121       NaN       NaN       NaN  ...           NaN        NaN       NaN
# 122       NaN       NaN       NaN  ...           NaN        NaN       NaN
#
#      R16L-2-T  R08H-2-Tc  R15H-2-T  R09L-4-Ta  R16L-5-T  R08H-2-Tb  R16L-1-T
# 0         NaN        NaN       NaN        1.0       NaN        NaN       NaN
# 1         NaN        NaN       NaN        NaN       NaN        NaN       NaN
# 2         1.0      318.0       1.0       17.0       2.0      166.0       3.0
# 3         NaN        NaN       NaN        NaN       NaN        1.0       NaN
# 4         NaN        NaN       NaN        NaN       NaN        NaN       NaN
# ..        ...        ...       ...        ...       ...        ...       ...
# 118       NaN        NaN       NaN        NaN       NaN        NaN       NaN
# 119       NaN        NaN       NaN        NaN       NaN        NaN       NaN
# 120       NaN        NaN       NaN        NaN       NaN        NaN       NaN
# 121       NaN        NaN       NaN        NaN       NaN        NaN       NaN
# 122       NaN        NaN       NaN        NaN       NaN        NaN       NaN
#
# [123 rows x 44 columns]

# %%
for col in pop.columns:
    sample_section+='\t\tSampleName="'+col+'"'+'\n'+'\t\tSampleSize='+str(sum(pop[col][pop[col]>0]))+'\n\t\tSampleData= {\n'
#     values=(pop[col][pop[col]>0].to_string())+'\n}\n\n'
    subset=pop[col][pop[col]>0]
    print(subset.index)
    values='\t\t\t'+'\n\t\t\t'.join([' '.join(map(str,[subset.index[i],subset.iloc[i]])) for i in range(len(subset))])
#     print(values)
    sample_section+=values+'\n\t\t}\n\n'
    
print(sample_section)
entry+=sample_section+'\n'
# Out:
# Int64Index([2, 5, 7, 8, 14, 31, 36, 53, 65, 73, 79, 81, 91, 96, 113, 115], dtype='int64')
# Int64Index([2, 9, 64, 70], dtype='int64')
# Int64Index([2, 4, 6, 7, 8, 9, 63, 66, 77, 94, 97, 115], dtype='int64')
# Int64Index([2, 7, 37, 52, 76, 83, 98, 101, 114], dtype='int64')
# Int64Index([2, 7, 9, 17, 35, 52, 58], dtype='int64')
# Int64Index([2, 7, 11, 12, 23, 33, 36, 45, 64, 65, 109], dtype='int64')
# Int64Index([0, 2, 9, 10, 12, 16], dtype='int64')
# Int64Index([2, 8, 9, 10, 15, 24, 27, 34, 49], dtype='int64')
# Int64Index([2, 5, 7, 8, 9, 70], dtype='int64')
# Int64Index([2, 4, 5, 6, 7, 8, 9, 15, 20, 30, 40, 47, 55, 63, 87, 104, 108,
#             114],
#            dtype='int64')
# Int64Index([2, 7, 8, 19, 33, 40, 114], dtype='int64')
# Int64Index([2, 3, 4, 10, 31, 41, 50, 60, 63, 76, 77, 93], dtype='int64')
# Int64Index([2, 5, 13, 17, 21, 30, 31, 36, 51, 65, 66, 71, 79, 115], dtype='int64')
# Int64Index([  2,   5,   7,   8,  17,  19,  23,  25,  33,  34,  38,  44,  51,
#              53,  67,  68,  76,  77,  79,  81,  87,  96,  97,  99, 111, 114],
#            dtype='int64')
# Int64Index([2, 4, 9], dtype='int64')
# Int64Index([2, 7, 9], dtype='int64')
# Int64Index([2, 3, 10, 11, 17, 26, 36, 39, 51, 97, 105, 110, 111], dtype='int64')
# Int64Index([8, 9, 15, 52], dtype='int64')
# Int64Index([2, 7, 9, 17, 33, 46, 53, 65, 87, 98, 99, 105, 114], dtype='int64')
# Int64Index([2, 7, 8, 16, 18, 33, 36, 49, 57, 97], dtype='int64')
# Int64Index([2, 7, 30, 31, 51, 63, 74, 88, 97, 102, 109, 111], dtype='int64')
# Int64Index([2, 11, 31, 38, 48, 50, 53, 85, 99], dtype='int64')
# Int64Index([2, 3, 8, 9, 16, 19, 21, 40, 45, 59, 63, 64, 86, 115], dtype='int64')
# Int64Index([0, 2, 4, 7, 8, 9, 13, 16, 17, 21, 31, 35, 43, 55, 65, 75, 76, 93,
#             98, 111],
#            dtype='int64')
# Int64Index([2, 5, 7, 8, 33, 37, 51, 55, 71, 77, 97, 111], dtype='int64')
# Int64Index([0, 1, 17, 18, 31, 33, 38, 116, 117, 120, 121, 122], dtype='int64')
# Int64Index([2, 4, 7, 10, 13, 19, 30, 36, 42, 45, 50, 53, 56, 58, 63, 65, 66,
#             71, 97],
#            dtype='int64')
# Int64Index([0, 1, 2, 7, 30, 31, 50, 78, 97, 118, 119], dtype='int64')
# Int64Index([2, 4, 7, 11, 50, 64, 76, 93], dtype='int64')
# Int64Index([2, 4, 5, 7, 8, 9, 11, 16, 36, 96, 97, 103, 109, 111, 112, 114,
#             115],
#            dtype='int64')
# Int64Index([2, 7, 9, 31, 35, 36, 90], dtype='int64')
# Int64Index([2, 5, 7, 8, 22, 83, 97], dtype='int64')
# Int64Index([2, 6, 7, 16, 18, 62, 63, 89], dtype='int64')
# Int64Index([0, 2, 9, 10, 24, 27, 50, 52, 65, 67, 69], dtype='int64')
# Int64Index([2, 5, 7, 9, 15, 29, 63, 67, 69], dtype='int64')
# Int64Index([2, 5, 7, 8, 18, 28, 33, 37, 52, 53, 65, 75, 87, 88, 97, 114], dtype='int64')
# Int64Index([2, 4, 7, 8, 9, 15, 52, 61, 64, 75, 80, 92, 97], dtype='int64')
# Int64Index([2, 9, 24, 70], dtype='int64')
# Int64Index([2, 7, 8, 11, 13, 16, 19, 30, 35, 76, 82, 106], dtype='int64')
# Int64Index([2, 9, 54, 107], dtype='int64')
# Int64Index([0, 2, 5, 7, 8, 9, 12, 31, 72, 95, 96, 97], dtype='int64')
# Int64Index([2, 9, 32], dtype='int64')
# Int64Index([2, 3, 7, 8, 30, 49, 50, 75, 84, 97, 100], dtype='int64')
# Int64Index([2, 7, 8, 9], dtype='int64')
# 	[[Samples]]
#
# 		SampleName="R09L-3-T"
# 		SampleSize=227.0
# 		SampleData= {
# 			2 169.0
# 			5 40.0
# 			7 2.0
# 			8 3.0
# 			14 1.0
# 			31 1.0
# 			36 1.0
# 			53 1.0
# 			65 1.0
# 			73 1.0
# 			79 1.0
# 			81 2.0
# 			91 1.0
# 			96 1.0
# 			113 1.0
# 			115 1.0
# 		}
#
# 		SampleName="R16L-4-T"
# 		SampleSize=238.0
# 		SampleData= {
# 			2 2.0
# 			9 234.0
# 			64 1.0
# 			70 1.0
# 		}
#
# 		SampleName="R08H-1-T"
# 		SampleSize=241.0
# 		SampleData= {
# 			2 198.0
# 			4 1.0
# 			6 3.0
# 			7 5.0
# 			8 23.0
# 			9 1.0
# 			63 2.0
# 			66 1.0
# 			77 1.0
# 			94 1.0
# 			97 4.0
# 			115 1.0
# 		}
#
# 		SampleName="R07B-2-Tc"
# 		SampleSize=288.0
# 		SampleData= {
# 			2 8.0
# 			7 273.0
# 			37 1.0
# 			52 1.0
# 			76 1.0
# 			83 1.0
# 			98 1.0
# 			101 1.0
# 			114 1.0
# 		}
#
# 		SampleName="R07B-1-Ta"
# 		SampleSize=177.0
# 		SampleData= {
# 			2 106.0
# 			7 66.0
# 			9 1.0
# 			17 1.0
# 			35 1.0
# 			52 1.0
# 			58 1.0
# 		}
#
# 		SampleName="R02H-8-T"
# 		SampleSize=93.0
# 		SampleData= {
# 			2 83.0
# 			7 1.0
# 			11 1.0
# 			12 1.0
# 			23 1.0
# 			33 1.0
# 			36 1.0
# 			45 1.0
# 			64 1.0
# 			65 1.0
# 			109 1.0
# 		}
#
# 		SampleName="R15H-3-T"
# 		SampleSize=371.0
# 		SampleData= {
# 			0 1.0
# 			2 1.0
# 			9 366.0
# 			10 1.0
# 			12 1.0
# 			16 1.0
# 		}
#
# 		SampleName="R15H-7-T"
# 		SampleSize=620.0
# 		SampleData= {
# 			2 3.0
# 			8 1.0
# 			9 608.0
# 			10 1.0
# 			15 3.0
# 			24 1.0
# 			27 1.0
# 			34 1.0
# 			49 1.0
# 		}
#
# 		SampleName="R16L-3-T"
# 		SampleSize=441.0
# 		SampleData= {
# 			2 3.0
# 			5 1.0
# 			7 1.0
# 			8 1.0
# 			9 434.0
# 			70 1.0
# 		}
#
# 		SampleName="R07B-3-T"
# 		SampleSize=192.0
# 		SampleData= {
# 			2 97.0
# 			4 2.0
# 			5 1.0
# 			6 2.0
# 			7 67.0
# 			8 1.0
# 			9 9.0
# 			15 1.0
# 			20 1.0
# 			30 2.0
# 			40 1.0
# 			47 1.0
# 			55 1.0
# 			63 2.0
# 			87 1.0
# 			104 1.0
# 			108 1.0
# 			114 1.0
# 		}
#
# 		SampleName="R09L-2-Ta"
# 		SampleSize=234.0
# 		SampleData= {
# 			2 212.0
# 			7 9.0
# 			8 9.0
# 			19 1.0
# 			33 1.0
# 			40 1.0
# 			114 1.0
# 		}
#
# 		SampleName="R13L-5-T"
# 		SampleSize=187.0
# 		SampleData= {
# 			2 132.0
# 			3 43.0
# 			4 1.0
# 			10 1.0
# 			31 1.0
# 			41 1.0
# 			50 1.0
# 			60 1.0
# 			63 3.0
# 			76 1.0
# 			77 1.0
# 			93 1.0
# 		}
#
# 		SampleName="R08H-3-Tb"
# 		SampleSize=380.0
# 		SampleData= {
# 			2 366.0
# 			5 1.0
# 			13 1.0
# 			17 1.0
# 			21 1.0
# 			30 1.0
# 			31 1.0
# 			36 1.0
# 			51 1.0
# 			65 1.0
# 			66 2.0
# 			71 1.0
# 			79 1.0
# 			115 1.0
# 		}
#
# 		SampleName="R09L-2-Tc"
# 		SampleSize=454.0
# 		SampleData= {
# 			2 353.0
# 			5 1.0
# 			7 52.0
# 			8 20.0
# 			17 2.0
# 			19 1.0
# 			23 1.0
# 			25 1.0
# 			33 1.0
# 			34 1.0
# 			38 1.0
# 			44 1.0
# 			51 1.0
# 			53 1.0
# 			67 1.0
# 			68 1.0
# 			76 1.0
# 			77 1.0
# 			79 1.0
# 			81 1.0
# 			87 1.0
# 			96 1.0
# 			97 6.0
# 			99 1.0
# 			111 1.0
# 			114 1.0
# 		}
#
# 		SampleName="R15H-3-T_old"
# 		SampleSize=170.0
# 		SampleData= {
# 			2 1.0
# 			4 1.0
# 			9 168.0
# 		}
#
# 		SampleName="R07B-2-Tb"
# 		SampleSize=124.0
# 		SampleData= {
# 			2 12.0
# 			7 111.0
# 			9 1.0
# 		}
#
# 		SampleName="R01L-10-T"
# 		SampleSize=219.0
# 		SampleData= {
# 			2 205.0
# 			3 1.0
# 			10 1.0
# 			11 1.0
# 			17 2.0
# 			26 1.0
# 			36 1.0
# 			39 1.0
# 			51 2.0
# 			97 1.0
# 			105 1.0
# 			110 1.0
# 			111 1.0
# 		}
#
# 		SampleName="R15H-1-T"
# 		SampleSize=430.0
# 		SampleData= {
# 			8 1.0
# 			9 427.0
# 			15 1.0
# 			52 1.0
# 		}
#
# 		SampleName="R07B-1-Tb"
# 		SampleSize=250.0
# 		SampleData= {
# 			2 158.0
# 			7 80.0
# 			9 1.0
# 			17 1.0
# 			33 1.0
# 			46 1.0
# 			53 2.0
# 			65 1.0
# 			87 1.0
# 			98 1.0
# 			99 1.0
# 			105 1.0
# 			114 1.0
# 		}
#
# 		SampleName="R01L-12-T"
# 		SampleSize=52.0
# 		SampleData= {
# 			2 35.0
# 			7 2.0
# 			8 7.0
# 			16 1.0
# 			18 1.0
# 			33 1.0
# 			36 1.0
# 			49 1.0
# 			57 1.0
# 			97 2.0
# 		}
#
# 		SampleName="R07B-1-Tc"
# 		SampleSize=317.0
# 		SampleData= {
# 			2 302.0
# 			7 3.0
# 			30 2.0
# 			31 1.0
# 			51 1.0
# 			63 1.0
# 			74 1.0
# 			88 2.0
# 			97 1.0
# 			102 1.0
# 			109 1.0
# 			111 1.0
# 		}
#
# 		SampleName="R08H-3-Tc"
# 		SampleSize=198.0
# 		SampleData= {
# 			2 189.0
# 			11 1.0
# 			31 2.0
# 			38 1.0
# 			48 1.0
# 			50 1.0
# 			53 1.0
# 			85 1.0
# 			99 1.0
# 		}
#
# 		SampleName="R08H-3-Ta"
# 		SampleSize=346.0
# 		SampleData= {
# 			2 332.0
# 			3 1.0
# 			8 1.0
# 			9 2.0
# 			16 1.0
# 			19 1.0
# 			21 1.0
# 			40 1.0
# 			45 1.0
# 			59 1.0
# 			63 1.0
# 			64 1.0
# 			86 1.0
# 			115 1.0
# 		}
#
# 		SampleName="R02H-7-T"
# 		SampleSize=253.0
# 		SampleData= {
# 			0 1.0
# 			2 227.0
# 			4 2.0
# 			7 1.0
# 			8 2.0
# 			9 5.0
# 			13 1.0
# 			16 1.0
# 			17 1.0
# 			21 1.0
# 			31 2.0
# 			35 1.0
# 			43 1.0
# 			55 1.0
# 			65 1.0
# 			75 1.0
# 			76 1.0
# 			93 1.0
# 			98 1.0
# 			111 1.0
# 		}
#
# 		SampleName="R09L-2-Tb"
# 		SampleSize=216.0
# 		SampleData= {
# 			2 174.0
# 			5 1.0
# 			7 18.0
# 			8 10.0
# 			33 1.0
# 			37 1.0
# 			51 1.0
# 			55 1.0
# 			71 1.0
# 			77 1.0
# 			97 6.0
# 			111 1.0
# 		}
#
# 		SampleName="R14B-2-T"
# 		SampleSize=138.0
# 		SampleData= {
# 			0 116.0
# 			1 10.0
# 			17 2.0
# 			18 2.0
# 			31 1.0
# 			33 1.0
# 			38 1.0
# 			116 1.0
# 			117 1.0
# 			120 1.0
# 			121 1.0
# 			122 1.0
# 		}
#
# 		SampleName="R02H-8-T_bis"
# 		SampleSize=187.0
# 		SampleData= {
# 			2 139.0
# 			4 21.0
# 			7 4.0
# 			10 1.0
# 			13 2.0
# 			19 2.0
# 			30 1.0
# 			36 1.0
# 			42 1.0
# 			45 6.0
# 			50 1.0
# 			53 1.0
# 			56 1.0
# 			58 1.0
# 			63 1.0
# 			65 1.0
# 			66 1.0
# 			71 1.0
# 			97 1.0
# 		}
#
# 		SampleName="R14B-4-T"
# 		SampleSize=209.0
# 		SampleData= {
# 			0 4.0
# 			1 2.0
# 			2 194.0
# 			7 2.0
# 			30 1.0
# 			31 1.0
# 			50 1.0
# 			78 1.0
# 			97 1.0
# 			118 1.0
# 			119 1.0
# 		}
#
# 		SampleName="R13L-3-T"
# 		SampleSize=286.0
# 		SampleData= {
# 			2 7.0
# 			4 272.0
# 			7 1.0
# 			11 2.0
# 			50 1.0
# 			64 1.0
# 			76 1.0
# 			93 1.0
# 		}
#
# 		SampleName="R09L-4-Tc"
# 		SampleSize=207.0
# 		SampleData= {
# 			2 119.0
# 			4 1.0
# 			5 60.0
# 			7 13.0
# 			8 1.0
# 			9 1.0
# 			11 2.0
# 			16 1.0
# 			36 1.0
# 			96 1.0
# 			97 1.0
# 			103 1.0
# 			109 1.0
# 			111 1.0
# 			112 1.0
# 			114 1.0
# 			115 1.0
# 		}
#
# 		SampleName="R13L-4-T"
# 		SampleSize=297.0
# 		SampleData= {
# 			2 275.0
# 			7 1.0
# 			9 17.0
# 			31 1.0
# 			35 1.0
# 			36 1.0
# 			90 1.0
# 		}
#
# 		SampleName="R09L-4-Tb"
# 		SampleSize=151.0
# 		SampleData= {
# 			2 60.0
# 			5 73.0
# 			7 13.0
# 			8 2.0
# 			22 1.0
# 			83 1.0
# 			97 1.0
# 		}
#
# 		SampleName="R07B-1-Td"
# 		SampleSize=267.0
# 		SampleData= {
# 			2 210.0
# 			6 28.0
# 			7 18.0
# 			16 1.0
# 			18 2.0
# 			62 1.0
# 			63 6.0
# 			89 1.0
# 		}
#
# 		SampleName="R15H-6-T"
# 		SampleSize=588.0
# 		SampleData= {
# 			0 1.0
# 			2 9.0
# 			9 569.0
# 			10 1.0
# 			24 1.0
# 			27 2.0
# 			50 1.0
# 			52 1.0
# 			65 1.0
# 			67 1.0
# 			69 1.0
# 		}
#
# 		SampleName="R15H-2-T_bis"
# 		SampleSize=767.0
# 		SampleData= {
# 			2 5.0
# 			5 1.0
# 			7 2.0
# 			9 753.0
# 			15 2.0
# 			29 1.0
# 			63 1.0
# 			67 1.0
# 			69 1.0
# 		}
#
# 		SampleName="R08H-2-Ta"
# 		SampleSize=263.0
# 		SampleData= {
# 			2 219.0
# 			5 2.0
# 			7 21.0
# 			8 4.0
# 			18 1.0
# 			28 1.0
# 			33 1.0
# 			37 1.0
# 			52 1.0
# 			53 2.0
# 			65 3.0
# 			75 1.0
# 			87 1.0
# 			88 2.0
# 			97 2.0
# 			114 1.0
# 		}
#
# 		SampleName="R02H-9-T"
# 		SampleSize=127.0
# 		SampleData= {
# 			2 51.0
# 			4 1.0
# 			7 2.0
# 			8 61.0
# 			9 1.0
# 			15 3.0
# 			52 1.0
# 			61 1.0
# 			64 1.0
# 			75 1.0
# 			80 1.0
# 			92 1.0
# 			97 2.0
# 		}
#
# 		SampleName="R16L-2-T"
# 		SampleSize=583.0
# 		SampleData= {
# 			2 1.0
# 			9 580.0
# 			24 1.0
# 			70 1.0
# 		}
#
# 		SampleName="R08H-2-Tc"
# 		SampleSize=333.0
# 		SampleData= {
# 			2 318.0
# 			7 3.0
# 			8 1.0
# 			11 2.0
# 			13 1.0
# 			16 2.0
# 			19 1.0
# 			30 1.0
# 			35 1.0
# 			76 1.0
# 			82 1.0
# 			106 1.0
# 		}
#
# 		SampleName="R15H-2-T"
# 		SampleSize=465.0
# 		SampleData= {
# 			2 1.0
# 			9 462.0
# 			54 1.0
# 			107 1.0
# 		}
#
# 		SampleName="R09L-4-Ta"
# 		SampleSize=180.0
# 		SampleData= {
# 			0 1.0
# 			2 17.0
# 			5 26.0
# 			7 7.0
# 			8 120.0
# 			9 2.0
# 			12 1.0
# 			31 1.0
# 			72 1.0
# 			95 1.0
# 			96 1.0
# 			97 2.0
# 		}
#
# 		SampleName="R16L-5-T"
# 		SampleSize=500.0
# 		SampleData= {
# 			2 2.0
# 			9 496.0
# 			32 2.0
# 		}
#
# 		SampleName="R08H-2-Tb"
# 		SampleSize=210.0
# 		SampleData= {
# 			2 166.0
# 			3 1.0
# 			7 28.0
# 			8 6.0
# 			30 2.0
# 			49 1.0
# 			50 1.0
# 			75 1.0
# 			84 1.0
# 			97 1.0
# 			100 2.0
# 		}
#
# 		SampleName="R16L-1-T"
# 		SampleSize=185.0
# 		SampleData= {
# 			2 3.0
# 			7 2.0
# 			8 1.0
# 			9 179.0
# 		}

# %%
entry=profile_section+'\n'+header_dat+'\n'+dist_section+'\n\n'+sample_section+'\n'
with open(file+'.arptemplate', 'w') as the_file:
    the_file.write(entry)

# %% [markdown]
# ## Structure

# %%
### Structure by Site
import shutil

meta=pd.read_csv('../CRISPR_metadata.txt',sep='\t')
meta['Sample']=['_'.join(val.split('_')[1:]) for val in meta['Sample'].values]
meta

what='Site'
header_structure='\t[[Structure]]\n'
StructureName='Structured by '+what
NbGroups=len(set(meta[what].values))
structure_section=header_structure+'\n'+'StructureName="'+StructureName+'"\n'+'NbGroups='+str(NbGroups)+'\n'

for grp in set(meta[what].values):
    list_of_samples=meta[meta[what]==grp].Sample.values
    group='Group={\n'+'\n'.join(['"'+sam+'"' for sam in list_of_samples])+'\n}\n'
    structure_section+=group
print(structure_section)

shutil.copy(file+'.arptemplate', file+'_'+what+'.arp')
with open(file+'_'+what+'.arp', 'a') as the_file:
    the_file.write(structure_section+'\n')
# Out:
# 	[[Structure]]
#
# StructureName="Structured by Site"
# NbGroups=9
# Group={
# "R02H-7-T"
# "R02H-8-T_bis"
# "R02H-8-T"
# "R02H-9-T"
# }
# Group={
# "R09L-2-Ta"
# "R09L-2-Tb"
# "R09L-2-Tc"
# "R09L-3-T"
# "R09L-4-Ta"
# "R09L-4-Tb"
# "R09L-4-Tc"
# }
# Group={
# "R08H-1-T"
# "R08H-2-Ta"
# "R08H-2-Tb"
# "R08H-2-Tc"
# "R08H-3-Ta"
# "R08H-3-Tb"
# "R08H-3-Tc"
# }
# Group={
# "R16L-1-T"
# "R16L-2-T"
# "R16L-3-T"
# "R16L-4-T"
# "R16L-5-T"
# }
# Group={
# "R14B-2-T"
# "R14B-4-T"
# }
# Group={
# "R07B-1-Ta"
# "R07B-1-Tb"
# "R07B-1-Tc"
# "R07B-1-Td"
# "R07B-2-Tb"
# "R07B-2-Tc"
# "R07B-3-T"
# }
# Group={
# "R15H-1-T"
# "R15H-2-T"
# "R15H-2-T_bis"
# "R15H-3-T"
# "R15H-3-T_old"
# "R15H-6-T"
# "R15H-7-T"
# }
# Group={
# "R13L-3-T"
# "R13L-4-T"
# "R13L-5-T"
# }
# Group={
# "R01L-10-T"
# "R01L-12-T"
# }

# %%
### Structure by Region
import shutil

meta=pd.read_csv('../CRISPR_metadata.txt',sep='\t')
meta['Sample']=['_'.join(val.split('_')[1:]) for val in meta['Sample'].values]
meta

what='Region'
header_structure='\t[[Structure]]\n'
StructureName='Structured by '+what
NbGroups=len(set(meta[what].values))
structure_section=header_structure+'\n'+'StructureName="'+StructureName+'"\n'+'NbGroups='+str(NbGroups)+'\n'

for grp in set(meta[what].values):
    list_of_samples=meta[meta[what]==grp].Sample.values
    group='Group={\n'+'\n'.join(['"'+sam+'"' for sam in list_of_samples])+'\n}\n'
    structure_section+=group
print(structure_section)

shutil.copy(file+'.arptemplate', file+'_'+what+'.arp')
with open(file+'_'+what+'.arp', 'a') as the_file:
    the_file.write(structure_section+'\n')
# Out:
# 	[[Structure]]
#
# StructureName="Structured by Region"
# NbGroups=3
# Group={
# "R13L-3-T"
# "R13L-4-T"
# "R13L-5-T"
# "R14B-2-T"
# "R14B-4-T"
# }
# Group={
# "R15H-1-T"
# "R15H-2-T"
# "R15H-2-T_bis"
# "R15H-3-T"
# "R15H-3-T_old"
# "R15H-6-T"
# "R15H-7-T"
# "R16L-1-T"
# "R16L-2-T"
# "R16L-3-T"
# "R16L-4-T"
# "R16L-5-T"
# }
# Group={
# "R01L-10-T"
# "R01L-12-T"
# "R02H-7-T"
# "R02H-8-T_bis"
# "R02H-8-T"
# "R02H-9-T"
# "R07B-1-Ta"
# "R07B-1-Tb"
# "R07B-1-Tc"
# "R07B-1-Td"
# "R07B-2-Tb"
# "R07B-2-Tc"
# "R07B-3-T"
# "R08H-1-T"
# "R08H-2-Ta"
# "R08H-2-Tb"
# "R08H-2-Tc"
# "R08H-3-Ta"
# "R08H-3-Tb"
# "R08H-3-Tc"
# "R09L-2-Ta"
# "R09L-2-Tb"
# "R09L-2-Tc"
# "R09L-3-T"
# "R09L-4-Ta"
# "R09L-4-Tb"
# "R09L-4-Tc"
# }

# %%
### Structure by Region
import shutil

meta=pd.read_csv('../CRISPR_metadata.txt',sep='\t')
meta['Sample']=['_'.join(val.split('_')[1:]) for val in meta['Sample'].values]
meta

what='Flow'
header_structure='\t[[Structure]]\n'
StructureName='Structured by '+what
NbGroups=len(set(meta[what].values))
structure_section=header_structure+'\n'+'StructureName="'+StructureName+'"\n'+'NbGroups='+str(NbGroups)+'\n'

for grp in set(meta[what].values):
    list_of_samples=meta[meta[what]==grp].Sample.values
    group='Group={\n'+'\n'.join(['"'+sam+'"' for sam in list_of_samples])+'\n}\n'
    structure_section+=group
print(structure_section)

shutil.copy(file+'.arptemplate', file+'_'+what+'.arp')
with open(file+'_'+what+'.arp', 'a') as the_file:
    the_file.write(structure_section+'\n')
# Out:
# 	[[Structure]]
#
# StructureName="Structured by Flow"
# NbGroups=3
# Group={
# "R01L-10-T"
# "R01L-12-T"
# "R09L-2-Ta"
# "R09L-2-Tb"
# "R09L-2-Tc"
# "R09L-3-T"
# "R09L-4-Ta"
# "R09L-4-Tb"
# "R09L-4-Tc"
# "R16L-1-T"
# "R16L-2-T"
# "R16L-3-T"
# "R16L-4-T"
# "R16L-5-T"
# }
# Group={
# "R07B-1-Ta"
# "R07B-1-Tb"
# "R07B-1-Tc"
# "R07B-1-Td"
# "R07B-2-Tb"
# "R07B-2-Tc"
# "R07B-3-T"
# "R14B-2-T"
# "R14B-4-T"
# }
# Group={
# "R02H-7-T"
# "R02H-8-T_bis"
# "R02H-8-T"
# "R02H-9-T"
# "R08H-1-T"
# "R08H-2-Ta"
# "R08H-2-Tb"
# "R08H-2-Tc"
# "R08H-3-Ta"
# "R08H-3-Tb"
# "R08H-3-Tc"
# "R13L-3-T"
# "R13L-4-T"
# "R13L-5-T"
# "R15H-1-T"
# "R15H-2-T"
# "R15H-2-T_bis"
# "R15H-3-T"
# "R15H-3-T_old"
# "R15H-6-T"
# "R15H-7-T"
# }
