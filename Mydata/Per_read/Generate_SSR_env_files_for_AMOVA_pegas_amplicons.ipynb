# %%
import pandas as pd
import numpy as np

# %%
# Amplicons
amplicons = pd.read_csv('../Amplicons_haplotypes_all.txt', sep='\t',header=0, index_col=0)
amplicons['Sample'] = [item[12:] for item in amplicons.index.values]
amplicons.index=[item[12:] for item in amplicons.index.values]
amplicons=amplicons.sort_index()
amplicons

locus_dic={'LpxA':['LpxA_CC','LpxA_CT','LpxA_TC','LpxA_TT'],'PleD':['PleD_AA', 'PleD_GA','PleD_GG', 'PleD_AG'],'TufB':['TufB_AA', 'TufB_AC', 'TufB_GA', 'TufB_GC']}
# LpxA
locus='LpxA'

df = amplicons.loc[:,locus_dic[locus]+['Sample']]
df
# Out:
#               LpxA_CC  LpxA_CT  LpxA_TC  LpxA_TT        Sample
# R07B-1-Ta         134       98     41.0     24.0     R07B-1-Ta
# R07B-1-Tb         122       78     49.0     25.0     R07B-1-Tb
# R07B-1-Tc         189       71      4.0      2.0     R07B-1-Tc
# R07B-1-Td          99       61     23.0     10.0     R07B-1-Td
# R07B-2-Ta          51      169     17.0     30.0     R07B-2-Ta
# R07B-2-Tb          26       19    120.0     35.0     R07B-2-Tb
# R07B-2-Tc          15        7    209.0      8.0     R07B-2-Tc
# R07B-2-Td          62        2    504.0      5.0     R07B-2-Td
# R07B-3-T           94       91     26.0     20.0      R07B-3-T
# R08H-1-T          254       54     28.0      7.0      R08H-1-T
# R08H-2-Ta          33      245      9.0     45.0     R08H-2-Ta
# R08H-2-Tb          38      182     14.0     47.0     R08H-2-Tb
# R08H-2-Tc          18      265      NaN     10.0     R08H-2-Tc
# R08H-3-Ta         296       18      NaN      NaN     R08H-3-Ta
# R08H-3-Tb         328       75      3.0      4.0     R08H-3-Tb
# R08H-3-Tc         356       26      NaN      NaN     R08H-3-Tc
# R09L-2-Ta         171       96     20.0     19.0     R09L-2-Ta
# R09L-2-Tb         105      141     16.0     25.0     R09L-2-Tb
# R09L-2-Tc         169      127     40.0     23.0     R09L-2-Tc
# R09L-3-T          123      140      3.0      2.0      R09L-3-T
# R09L-4-Ta          54       84     48.0     49.0     R09L-4-Ta
# R09L-4-Tb          31      263      3.0     27.0     R09L-4-Tb
# R09L-4-Tc          32      293      6.0     40.0     R09L-4-Tc
# R13L-3-T           46      233      NaN      NaN      R13L-3-T
# R13L-4-T          202      132      NaN      NaN      R13L-4-T
# R13L-5-T          155      131      NaN      NaN      R13L-5-T
# R13L-5-T_bis      180      107      NaN      NaN  R13L-5-T_bis
# R14B-2-T          257        1      2.0      NaN      R14B-2-T
# R14B-3-T          229        3      NaN      NaN      R14B-3-T
# R14B-4-T          329        1      NaN      NaN      R14B-4-T
# R15H-1-T           93        1      NaN      NaN      R15H-1-T
# R15H-2-T          343        3      NaN      NaN      R15H-2-T
# R15H-3-T          246        1      NaN      NaN      R15H-3-T
# R15H-3-T_old      102        1      NaN      NaN  R15H-3-T_old
# R16L-1-T          308        1      NaN      NaN      R16L-1-T
# R16L-2-T          249        3      NaN      NaN      R16L-2-T
# R16L-3-T          376        1      NaN      NaN      R16L-3-T
# R16L-3-T_bis       95        3      NaN      NaN  R16L-3-T_bis

# %%
df2=pd.DataFrame(columns=['Sample','read_id'])

for i in range(0,len(df.columns)-1):
    print(i)
    d=df.iloc[:,[i,len(df.columns)-1]].dropna()
#     print(d)
    idx=df.columns[i]
    d=d[idx].apply(lambda x: range(int(x))).explode()
    print(d)
    dic={'read_id':['_'.join(item) for item in list(zip(list(d.index),[str(idx)]*len(d.index),map(str,d.values)))],'Sample':list(d.index.values),str(i):[1]*len(d.index)}
    dic
    newdf=pd.DataFrame.from_dict(dic)
    newdf
    df2=df2.append(newdf,ignore_index=True)
df2['haplo']=df2.read_id.apply(lambda x: str(x.split('_')[-2]))
df2['ind']=df2.read_id.apply(lambda x: int(x.split('_')[-1]))
df2.index=df2.read_id
df2.sort_values(by=['Sample','haplo','ind'], inplace=True)
df2
d=df2[['Sample','read_id','haplo','ind']]

d

# d.to_csv(locus+'_per_read.txt',header=True,index=True,sep='\t')
df2
# Out:
# 0
# R07B-1-Ta        0
# R07B-1-Ta        1
# R07B-1-Ta        2
# R07B-1-Ta        3
# R07B-1-Ta        4
#                 ..
# R16L-3-T_bis    90
# R16L-3-T_bis    91
# R16L-3-T_bis    92
# R16L-3-T_bis    93
# R16L-3-T_bis    94
# Name: LpxA_CC, Length: 6010, dtype: object
# 1
# R07B-1-Ta       0
# R07B-1-Ta       1
# R07B-1-Ta       2
# R07B-1-Ta       3
# R07B-1-Ta       4
#                ..
# R16L-2-T        2
# R16L-3-T        0
# R16L-3-T_bis    0
# R16L-3-T_bis    1
# R16L-3-T_bis    2
# Name: LpxA_CT, Length: 3227, dtype: object
# 2
# R07B-1-Ta    0
# R07B-1-Ta    1
# R07B-1-Ta    2
# R07B-1-Ta    3
# R07B-1-Ta    4
#             ..
# R09L-4-Tc    3
# R09L-4-Tc    4
# R09L-4-Tc    5
# R14B-2-T     0
# R14B-2-T     1
# Name: LpxA_TC, Length: 1185, dtype: object
# 3
# R07B-1-Ta     0
# R07B-1-Ta     1
# R07B-1-Ta     2
# R07B-1-Ta     3
# R07B-1-Ta     4
#              ..
# R09L-4-Tc    35
# R09L-4-Tc    36
# R09L-4-Tc    37
# R09L-4-Tc    38
# R09L-4-Tc    39
# Name: LpxA_TT, Length: 457, dtype: object
#                                Sample                  read_id    0    1   2  \
# read_id
# R07B-1-Ta_LpxA_CC_0         R07B-1-Ta      R07B-1-Ta_LpxA_CC_0  1.0  NaN NaN
# R07B-1-Ta_LpxA_CC_1         R07B-1-Ta      R07B-1-Ta_LpxA_CC_1  1.0  NaN NaN
# R07B-1-Ta_LpxA_CC_2         R07B-1-Ta      R07B-1-Ta_LpxA_CC_2  1.0  NaN NaN
# R07B-1-Ta_LpxA_CC_3         R07B-1-Ta      R07B-1-Ta_LpxA_CC_3  1.0  NaN NaN
# R07B-1-Ta_LpxA_CC_4         R07B-1-Ta      R07B-1-Ta_LpxA_CC_4  1.0  NaN NaN
# ...                               ...                      ...  ...  ...  ..
# R16L-3-T_bis_LpxA_CC_93  R16L-3-T_bis  R16L-3-T_bis_LpxA_CC_93  1.0  NaN NaN
# R16L-3-T_bis_LpxA_CC_94  R16L-3-T_bis  R16L-3-T_bis_LpxA_CC_94  1.0  NaN NaN
# R16L-3-T_bis_LpxA_CT_0   R16L-3-T_bis   R16L-3-T_bis_LpxA_CT_0  NaN  1.0 NaN
# R16L-3-T_bis_LpxA_CT_1   R16L-3-T_bis   R16L-3-T_bis_LpxA_CT_1  NaN  1.0 NaN
# R16L-3-T_bis_LpxA_CT_2   R16L-3-T_bis   R16L-3-T_bis_LpxA_CT_2  NaN  1.0 NaN
#
#                           3 haplo  ind
# read_id
# R07B-1-Ta_LpxA_CC_0     NaN    CC    0
# R07B-1-Ta_LpxA_CC_1     NaN    CC    1
# R07B-1-Ta_LpxA_CC_2     NaN    CC    2
# R07B-1-Ta_LpxA_CC_3     NaN    CC    3
# R07B-1-Ta_LpxA_CC_4     NaN    CC    4
# ...                      ..   ...  ...
# R16L-3-T_bis_LpxA_CC_93 NaN    CC   93
# R16L-3-T_bis_LpxA_CC_94 NaN    CC   94
# R16L-3-T_bis_LpxA_CT_0  NaN    CT    0
# R16L-3-T_bis_LpxA_CT_1  NaN    CT    1
# R16L-3-T_bis_LpxA_CT_2  NaN    CT    2
#
# [10879 rows x 8 columns]

# %% [markdown]
# # Create Genepop file

# %%
pop=d[['Sample','haplo']]
pop
# Out:
#                                Sample haplo
# read_id
# R07B-1-Ta_LpxA_CC_0         R07B-1-Ta    CC
# R07B-1-Ta_LpxA_CC_1         R07B-1-Ta    CC
# R07B-1-Ta_LpxA_CC_2         R07B-1-Ta    CC
# R07B-1-Ta_LpxA_CC_3         R07B-1-Ta    CC
# R07B-1-Ta_LpxA_CC_4         R07B-1-Ta    CC
# ...                               ...   ...
# R16L-3-T_bis_LpxA_CC_93  R16L-3-T_bis    CC
# R16L-3-T_bis_LpxA_CC_94  R16L-3-T_bis    CC
# R16L-3-T_bis_LpxA_CT_0   R16L-3-T_bis    CT
# R16L-3-T_bis_LpxA_CT_1   R16L-3-T_bis    CT
# R16L-3-T_bis_LpxA_CT_2   R16L-3-T_bis    CT
#
# [10879 rows x 2 columns]

# %%
entry='Title line: "Ridgeia symbiont populations in trophosomes"\nMicroSat 1\n'

for sample in set(pop.Sample.values):
    print(sample)
    spop=pop[pop['Sample']==sample]
    spop=spop.to_string(header=False,index=False)
    entry+="pop\n"+spop+'\n'
    break
# with open(locus+"_per_read.genpop",'w') as fa:
#     fa.write(entry)
# print(entry)
# Out:
# R08H-2-Tc
# Title line: "Ridgeia symbiont populations in trophosomes"
# MicroSat 1
# pop
#  R08H-2-Tc  CC
#  R08H-2-Tc  CC
#  R08H-2-Tc  CC
#  R08H-2-Tc  CC
#  R08H-2-Tc  CC
#  R08H-2-Tc  CC
#  R08H-2-Tc  CC
#  R08H-2-Tc  CC
#  R08H-2-Tc  CC
#  R08H-2-Tc  CC
#  R08H-2-Tc  CC
#  R08H-2-Tc  CC
#  R08H-2-Tc  CC
#  R08H-2-Tc  CC
#  R08H-2-Tc  CC
#  R08H-2-Tc  CC
#  R08H-2-Tc  CC
#  R08H-2-Tc  CC
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  CT
#  R08H-2-Tc  TT
#  R08H-2-Tc  TT
#  R08H-2-Tc  TT
#  R08H-2-Tc  TT
#  R08H-2-Tc  TT
#  R08H-2-Tc  TT
#  R08H-2-Tc  TT
#  R08H-2-Tc  TT
#  R08H-2-Tc  TT
#  R08H-2-Tc  TT

# %% [markdown]
# # Create Structure file
#
# The input file is fairly easy:
# _ first line: marker names separated by space
# _ second line (optional): phase information, ...
# _ all next lines are your individual (name, population, genotype at the markers)

# %%
entry=locus+'\n'
print(len(pop))
print(len(set(pop.Sample.values)))
pop_dip=pop
# pop_dip.to_csv(locus+'_per_read.stru',header=False,index=True,index_label=False,sep='\t')
pop_dip
# Out:
# 10879
# 38
#                                Sample haplo
# read_id
# R07B-1-Ta_LpxA_CC_0         R07B-1-Ta    CC
# R07B-1-Ta_LpxA_CC_1         R07B-1-Ta    CC
# R07B-1-Ta_LpxA_CC_2         R07B-1-Ta    CC
# R07B-1-Ta_LpxA_CC_3         R07B-1-Ta    CC
# R07B-1-Ta_LpxA_CC_4         R07B-1-Ta    CC
# ...                               ...   ...
# R16L-3-T_bis_LpxA_CC_93  R16L-3-T_bis    CC
# R16L-3-T_bis_LpxA_CC_94  R16L-3-T_bis    CC
# R16L-3-T_bis_LpxA_CT_0   R16L-3-T_bis    CT
# R16L-3-T_bis_LpxA_CT_1   R16L-3-T_bis    CT
# R16L-3-T_bis_LpxA_CT_2   R16L-3-T_bis    CT
#
# [10879 rows x 2 columns]

# %% [markdown]
# # Create SSR file

# %%
# # dist=pd.read_csv('./Runs_on_cluster/run2/arrays_in_whole_dataset_v6_noneg_pairwiseDist.csv',header=0,index_col=0,sep='\t')
# dist=pd.read_csv('all_arrays_with_at_least_5percent_in_reads.dist',header=0,sep='\t')

# dist.iloc[0,0]
# dist


# dic_fill={}
# for i in range(len(dist)):
#     dic_fill[i]=[dist.iloc[i,int(j)] for j in df2.haplo.values]
    
    
# print(len(dic_fill))        

# df3=pd.DataFrame(columns=df2.index,index=df2.index)

# for i in range(len(df3.index)):
#     haplo=int(df3.iloc[i].name.split('_')[-2])
#     df3.iloc[i]=dic_fill[haplo]

# df3.to_csv('all_arrays_v6_noneg_pairwiseDist_per_read.csv',header=True,index=True,sep='\t', chunksize=100000, compression='gzip' , encoding='utf-8')
# Out:
#           0         1         2         3         4         5         6  \
# 0       NaN  0.954284  2.732832  3.299743  3.299743  3.287410  3.894154
# 1  0.954284       NaN  3.337040  3.903952  3.903952  3.891619  4.498363
# 2  2.732832  3.337040       NaN  0.568317  0.568317  0.554579  1.162728
# 3  3.299743  3.903952  0.568317       NaN  0.972637  1.122896  1.567047
# 4  3.299743  3.903952  0.568317  0.972637       NaN  1.122896  1.428660
# 5  3.287410  3.891619  0.554579  1.122896  1.122896       NaN  1.717306
# 6  3.894154  4.498363  1.162728  1.567047  1.428660  1.717306       NaN
# 7  3.313079  3.917288  0.581653  0.985972  0.847585  1.136232  0.581075
# 8  3.978915  4.583124  1.247489  1.651808  1.513421  1.802067  1.250807
# 9  6.913881  7.518090  4.182455  4.586774  4.448388  4.737034  4.185774
#
#           7         8         9
# 0  3.313079  3.978915  6.913881
# 1  3.917288  4.583124  7.518090
# 2  0.581653  1.247489  4.182455
# 3  0.985972  1.651808  4.586774
# 4  0.847585  1.513421  4.448388
# 5  1.136232  1.802067  4.737034
# 6  0.581075  1.250807  4.185774
# 7       NaN  0.669732  3.604699
# 8  0.669732       NaN  2.934967
# 9  3.604699  2.934967       NaN

# %% [markdown]
# # Create env file

# %%
meta=pd.read_csv('../Amplicons_metadata.txt',header=0,sep='\t')
meta['Sample']=meta.Sample.apply(lambda x: x[4:])
meta
# Out:
#           Sample Sample_id  Site Region Flow     Ind Duplicate    seqid
# 0       R14B-2-T       A01  R14B     CB    B  R14B-2         n  FLD0094
# 1       R14B-3-T       A02  R14B     CB    B  R14B-3         n  FLD0060
# 2       R14B-4-T       A03  R14B     CB    B  R14B-4         n  FLD0092
# 3       R13L-4-T       A04  R13L     CB    H  R13L-4         n  FLD0091
# 4       R13L-5-T       A05  R13L     CB    H  R13L-5         y  FLD0062
# 5   R13L-5-T_bis       A05  R13L     CB    H  R13L-5         y  FLD0090
# 6       R13L-3-T       A06  R13L     CB    H  R13L-3         n  FLD0089
# 7       R15H-1-T       A07  R15H     MV    H  R15H-1         n  FLD0070
# 8       R15H-2-T       A08  R15H     MV    H  R15H-2         n  FLD0088
# 9       R15H-3-T       A09  R15H     MV    H  R15H-3         y  FLD0056
# 10  R15H-3-T_old       A09  R15H     MV    H  R15H-3         y  FLD0087
# 11      R16L-1-T       A10  R16L     MV    L  R16L-1         n  FLD0086
# 12      R16L-2-T       A11  R16L     MV    L  R16L-2         n  FLD0085
# 13      R16L-3-T       A12  R16L     MV    L  R16L-3         y  FLD0061
# 14  R16L-3-T_bis       A12  R16L     MV    L  R16L-3         y  FLD0084
# 15     R07B-1-Ta       A13  R07B    MEF    B  R07B-1         n  FLD0083
# 16     R07B-1-Tb       A14  R07B    MEF    B  R07B-1         n  FLD0082
# 17     R07B-1-Tc       A15  R07B    MEF    B  R07B-1         n  FLD0081
# 18     R07B-1-Td       A16  R07B    MEF    B  R07B-1         n  FLD0080
# 19     R07B-2-Ta       A17  R07B    MEF    B  R07B-2         n  FLD0052
# 20     R07B-2-Tb       A18  R07B    MEF    B  R07B-2         n  FLD0053
# 21     R07B-2-Tc       A19  R07B    MEF    B  R07B-2         n  FLD0054
# 22     R07B-2-Td       A20  R07B    MEF    B  R07B-2         n  FLD0055
# 23      R07B-3-T       A21  R07B    MEF    B  R07B-3         n  FLD0079
# 24      R08H-1-T       A22  R08H    MEF    H  R08H-1         n  FLD0057
# 25     R08H-2-Ta       A23  R08H    MEF    H  R08H-2         n  FLD0064
# 26     R08H-2-Tb       A24  R08H    MEF    H  R08H-2         n  FLD0058
# 27     R08H-2-Tc       A25  R08H    MEF    H  R08H-2         n  FLD0078
# 28     R08H-3-Ta       A26  R08H    MEF    H  R08H-3         n  FLD0059
# 29     R08H-3-Tb       A27  R08H    MEF    H  R08H-3         n  FLD0076
# 30     R08H-3-Tc       A28  R08H    MEF    H  R08H-3         n  FLD0075
# 31     R09L-2-Ta       A29  R09L    MEF    L  R09L-2         n  FLD0074
# 32     R09L-2-Tb       A30  R09L    MEF    L  R09L-2         n  FLD0073
# 33     R09L-2-Tc       A31  R09L    MEF    L  R09L-2         n  FLD0072
# 34      R09L-3-T       A32  R09L    MEF    L  R09L-3         n  FLD0071
# 35     R09L-4-Ta       A33  R09L    MEF    L  R09L-4         n  FLD0049
# 36     R09L-4-Tb       A34  R09L    MEF    L  R09L-4         n  FLD0050
# 37     R09L-4-Tc       A35  R09L    MEF    L  R09L-4         n  FLD0051

# %%
rmeta=pd.merge(df2.loc[:,['read_id','Sample','haplo']],meta,on='Sample')
rmeta.to_csv(locus+'_per_read_AMOVA_poppr.csv',sep='\t',header=True,index=False)
rmeta
# Out:
#                        read_id        Sample haplo Sample_id  Site Region  \
# 0          R07B-1-Ta_LpxA_CC_0     R07B-1-Ta    CC       A13  R07B    MEF
# 1          R07B-1-Ta_LpxA_CC_1     R07B-1-Ta    CC       A13  R07B    MEF
# 2          R07B-1-Ta_LpxA_CC_2     R07B-1-Ta    CC       A13  R07B    MEF
# 3          R07B-1-Ta_LpxA_CC_3     R07B-1-Ta    CC       A13  R07B    MEF
# 4          R07B-1-Ta_LpxA_CC_4     R07B-1-Ta    CC       A13  R07B    MEF
# ...                        ...           ...   ...       ...   ...    ...
# 10874  R16L-3-T_bis_LpxA_CC_93  R16L-3-T_bis    CC       A12  R16L     MV
# 10875  R16L-3-T_bis_LpxA_CC_94  R16L-3-T_bis    CC       A12  R16L     MV
# 10876   R16L-3-T_bis_LpxA_CT_0  R16L-3-T_bis    CT       A12  R16L     MV
# 10877   R16L-3-T_bis_LpxA_CT_1  R16L-3-T_bis    CT       A12  R16L     MV
# 10878   R16L-3-T_bis_LpxA_CT_2  R16L-3-T_bis    CT       A12  R16L     MV
#
#       Flow     Ind Duplicate    seqid
# 0        B  R07B-1         n  FLD0083
# 1        B  R07B-1         n  FLD0083
# 2        B  R07B-1         n  FLD0083
# 3        B  R07B-1         n  FLD0083
# 4        B  R07B-1         n  FLD0083
# ...    ...     ...       ...      ...
# 10874    L  R16L-3         y  FLD0084
# 10875    L  R16L-3         y  FLD0084
# 10876    L  R16L-3         y  FLD0084
# 10877    L  R16L-3         y  FLD0084
# 10878    L  R16L-3         y  FLD0084
#
# [10879 rows x 10 columns]

# %%
df2
# Out:
#                                Sample                  read_id    0    1   2  \
# read_id
# R07B-1-Ta_LpxA_CC_0         R07B-1-Ta      R07B-1-Ta_LpxA_CC_0  1.0  NaN NaN
# R07B-1-Ta_LpxA_CC_1         R07B-1-Ta      R07B-1-Ta_LpxA_CC_1  1.0  NaN NaN
# R07B-1-Ta_LpxA_CC_2         R07B-1-Ta      R07B-1-Ta_LpxA_CC_2  1.0  NaN NaN
# R07B-1-Ta_LpxA_CC_3         R07B-1-Ta      R07B-1-Ta_LpxA_CC_3  1.0  NaN NaN
# R07B-1-Ta_LpxA_CC_4         R07B-1-Ta      R07B-1-Ta_LpxA_CC_4  1.0  NaN NaN
# ...                               ...                      ...  ...  ...  ..
# R16L-3-T_bis_LpxA_CC_93  R16L-3-T_bis  R16L-3-T_bis_LpxA_CC_93  1.0  NaN NaN
# R16L-3-T_bis_LpxA_CC_94  R16L-3-T_bis  R16L-3-T_bis_LpxA_CC_94  1.0  NaN NaN
# R16L-3-T_bis_LpxA_CT_0   R16L-3-T_bis   R16L-3-T_bis_LpxA_CT_0  NaN  1.0 NaN
# R16L-3-T_bis_LpxA_CT_1   R16L-3-T_bis   R16L-3-T_bis_LpxA_CT_1  NaN  1.0 NaN
# R16L-3-T_bis_LpxA_CT_2   R16L-3-T_bis   R16L-3-T_bis_LpxA_CT_2  NaN  1.0 NaN
#
#                           3 haplo  ind
# read_id
# R07B-1-Ta_LpxA_CC_0     NaN    CC    0
# R07B-1-Ta_LpxA_CC_1     NaN    CC    1
# R07B-1-Ta_LpxA_CC_2     NaN    CC    2
# R07B-1-Ta_LpxA_CC_3     NaN    CC    3
# R07B-1-Ta_LpxA_CC_4     NaN    CC    4
# ...                      ..   ...  ...
# R16L-3-T_bis_LpxA_CC_93 NaN    CC   93
# R16L-3-T_bis_LpxA_CC_94 NaN    CC   94
# R16L-3-T_bis_LpxA_CT_0  NaN    CT    0
# R16L-3-T_bis_LpxA_CT_1  NaN    CT    1
# R16L-3-T_bis_LpxA_CT_2  NaN    CT    2
#
# [10879 rows x 8 columns]
